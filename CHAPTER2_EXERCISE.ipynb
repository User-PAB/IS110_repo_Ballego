# %%
EXERCISE 1

# %%
name= input("Enter your name: ")
print("Hello", name)

# %%
EXERCISE 2
# Out:
#   File "/tmp/ipython-input-3996834858.py", line 1
#     EXERCISE 2
#              ^
# SyntaxError: invalid syntax

# %%
rate= input('Enter rate: ')
hours= input("Enter Hours: ")
pay= float(rate)*float(hours)
print("Pay:", pay)

# %%
EXERCISE 3

# %%
width = 17
height = 12.0

print("width//2= ", width//2)
print("width/2.0= ", width/2)
print("height/3= ", height/3)
print("1 + 2 * 5= ", 1 + 2 * 5)

# %%
EXERCISE 4

# %%
number= input("Enter a number: ")
print("The square of", number, "is", int(number)**2)

# %%
CHALLENGE

# %%
celsius= input("Enter a Celsius temperature: ")
fahrenheit= float(celsius)*9/5+32
print(celsius, "degrees Celsius is:", fahrenheit)
