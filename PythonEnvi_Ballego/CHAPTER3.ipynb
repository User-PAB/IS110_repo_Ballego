# %%
CHAPTER 3
# Out:
#   File "/tmp/ipykernel_157/3116231640.py", line 1
#     CHAPTER 3
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Exercise 1

# %%
x = int(input("Declare the value of X: "));
if x >= 0 and x < 10:
    print('Equal to or above 0')
elif x >= 10 and x < 20:
    print('Equal to or above 10')
elif x >= 50:
    print('Equal to or above 50')
elif x >= 20 and x < 50:
    print('Equal to or above 20')
else:
    print('Something else')

# %%
EXCERCISE 2

# %%
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

if hours <= 40:
    pay = hours * rate
else:
    regular = 40 * rate
    overtime = (hours - 40) * rate * 1.5
    pay = regular + overtime

print("Pay:", pay)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %%
CHALLENGE

# %%
score = float(input("Enter score (0-100): "))

if score < 0 or score > 100:
    print("Error: Score must be between 0 and 100")
elif score >= 98:
    grade = 1.0
elif score >= 94:
    grade = 1.25
elif score >= 90:
    grade = 1.5
elif score >= 86:
    grade = 1.75
elif score >= 82:
    grade = 2.0
elif score >= 78:
    grade = 2.25
elif score >= 75:
    grade = 2.5
else:
    grade = 5.0

print(f"Grade: {grade}")
# Out:
# Enter score (0-100): 88
# Grade: 1.75
